# %% [markdown]
# # Section 1: Introduction
#
# In this section, we want to answer the following questions:
# - How has the number of opioid-related deaths in California changed from 2015 to 2021?
# - Which counties have the highest growth rate in terms of death rates per 100K residents?
# - Which counties have the most number of deaths? Which counties have the highest death rates per 100K residents?
# - How does it look on the California map?

# %%
# Import libraries
# %matplotlib inline

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# increase the size and quality of any plots we produce
import matplotlib as mpl

mpl.rcParams["figure.dpi"] = 200

# %%
# Load data
opioid_df = pd.read_csv("https://raw.githubusercontent.com/mellanyquiroz/DS4A-TeamProject/master/data/Pre-merging/Opioid_Deaths_by_County_2015-2020.csv")
opioid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   County  360 non-null    object
#  1   Rates   354 non-null    float64
#  2   Counts  360 non-null    float64
#  3   Year    360 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 11.4+ KB

# %%
# Fill null values in Rates column. They are most likely counties with no death counts and zero rate. Let's replace them with zeros
opioid_df = opioid_df.fillna(0)
opioid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   County  360 non-null    object
#  1   Rates   360 non-null    float64
#  2   Counts  360 non-null    float64
#  3   Year    360 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 11.4+ KB

# %%
# Check the statistical distributions of the data
opioid_df.describe()
# Out:
#             Rates       Counts         Year
# count  360.000000   360.000000   360.000000
# mean     7.731583    96.661111  2017.500000
# std      6.663298   414.086963     1.710202
# min      0.000000     0.000000  2015.000000
# 25%      3.307500     3.000000  2016.000000
# 50%      6.215000    14.000000  2017.500000
# 75%     10.052500    46.000000  2019.000000
# max     44.510000  5502.000000  2020.000000

# %%
# Check county column
print(opioid_df["County"].unique())
# Out:
# ['Alameda' 'Alpine' 'Amador' 'Butte' 'Calaveras' 'California' 'Colusa'
#  'Contra Costa' 'Del Norte' 'El Dorado' 'Fresno' 'Glenn' 'Humboldt'
#  'Imperial' 'Inyo' 'Kern' 'Kings' 'Lake' 'Lassen' 'Los Angeles' 'Madera'
#  'Marin' 'Mariposa' 'Mendocino' 'Merced' 'Modoc' 'Mono' 'Monterey' 'Napa'
#  'Nevada' 'Orange' 'Placer' 'Plumas' 'Riverside' 'Sacramento' 'San Benito'
#  'San Bernardino' 'San Diego' 'San Francisco' 'San Joaquin'
#  'San Luis Obispo' 'San Mateo' 'Santa Barbara' 'Santa Clara' 'Santa Cruz'
#  'Shasta' 'Sierra' 'Siskiyou' 'Solano' 'Sonoma' 'Stanislaus' 'Sutter'
#  'Tehama' 'Trinity' 'Tulare' 'Tuolumne' 'Unknown' 'Ventura' 'Yolo' 'Yuba']

# %% [markdown]
# We see that there is "California" in the County column. This must be the sum of all counties' numbers. We take it out of the county dataframe and conduct separate analysis for California as a whole.

# %%
# Take out California
cali_opioid = opioid_df[opioid_df["County"] == "California"]
cali_opioid.head()
# Out:
#          County  Rates  Counts  Year
# 5    California   4.79  1992.0  2015
# 65   California   4.87  2039.0  2016
# 125  California   5.22  2194.0  2017
# 185  California   5.82  2428.0  2018
# 245  California   7.90  3244.0  2019

# %%
# Remove California from county data
county_opioid = opioid_df[opioid_df["County"] != "California"]
print(county_opioid["County"].unique())
# Out:
# ['Alameda' 'Alpine' 'Amador' 'Butte' 'Calaveras' 'Colusa' 'Contra Costa'
#  'Del Norte' 'El Dorado' 'Fresno' 'Glenn' 'Humboldt' 'Imperial' 'Inyo'
#  'Kern' 'Kings' 'Lake' 'Lassen' 'Los Angeles' 'Madera' 'Marin' 'Mariposa'
#  'Mendocino' 'Merced' 'Modoc' 'Mono' 'Monterey' 'Napa' 'Nevada' 'Orange'
#  'Placer' 'Plumas' 'Riverside' 'Sacramento' 'San Benito' 'San Bernardino'
#  'San Diego' 'San Francisco' 'San Joaquin' 'San Luis Obispo' 'San Mateo'
#  'Santa Barbara' 'Santa Clara' 'Santa Cruz' 'Shasta' 'Sierra' 'Siskiyou'
#  'Solano' 'Sonoma' 'Stanislaus' 'Sutter' 'Tehama' 'Trinity' 'Tulare'
#  'Tuolumne' 'Unknown' 'Ventura' 'Yolo' 'Yuba']

# %% [markdown]
# ### Death Rates and Counts in California from 2015 - 2021

# %%
# Plot California death counts and rates 2015 - 2021
fig,ax1 = plt.subplots()
x = cali_opioid["Year"]
y1 = cali_opioid["Counts"]
y2 = cali_opioid["Rates"]

color = 'tab:blue'
ax1.set_xlabel("Year")
ax1.set_ylabel("Death Counts")
ax1.set_title("Opioid-related Death Counts and Rates in California 2015-2021")
ax1.bar(x,y1,color=color)

color = 'tab:red'
ax2 = ax1.twinx()
ax2.set_ylabel("Death Rates per 100K residents")
ax2.plot(x,y2,color=color)

plt.show()

# %% [markdown]
# Takeaway: Both death counts and rates have been significantly increasing since 2015. In 2019 and 2020, death rates almost doubled every year.

# %% [markdown]
# ### Death Rates and Counts in different counties
#
# California is a big state. One way to dig deeper into this trend is to look at the numbers geographically (by county). Next, we will explore how opioid-related deaths and counts change in different counties in CA.

# %%
# Calculate the growth in death rates 2018 - 2019 and 2019 - 2020
year_2018 = county_opioid[county_opioid["Year"] == 2018]
year_2019 = county_opioid[county_opioid["Year"] == 2019]
year_2020 = county_opioid[county_opioid["Year"] == 2020]

growthrates = pd.merge(year_2018,year_2019,on="County",suffixes=(2018,2019))
county_opioid_rates = pd.merge(growthrates,year_2020,on="County")
county_opioid_rates.head()
# Out:
#       County  Rates2018  Counts2018  Year2018  Rates2019  Counts2019  \
# 0    Alameda       3.10        56.0      2018       5.75       103.0
# 1     Alpine       0.00         0.0      2018       0.00         0.0
# 2     Amador       2.90         1.0      2018       7.81         5.0
# 3      Butte       6.55        17.0      2018       5.83        12.0
# 4  Calaveras       9.71         3.0      2018       7.79         4.0
#
#    Year2019  Rates  Counts  Year
# 0      2019   8.09   144.0  2020
# 1      2019   0.00     0.0  2020
# 2      2019  13.07     4.0  2020
# 3      2019  11.54    26.0  2020
# 4      2019   7.00     2.0  2020

# %%
# Remove and rename columns
county_opioid_rates = county_opioid_rates.drop(columns=["Year2018","Year2019","Year"])
county_opioid_rates = county_opioid_rates.rename(columns={"Rates":"Rates2020","Counts":"Counts2020"})
county_opioid_rates.head()
# Out:
#       County  Rates2018  Counts2018  Rates2019  Counts2019  Rates2020  \
# 0    Alameda       3.10        56.0       5.75       103.0       8.09
# 1     Alpine       0.00         0.0       0.00         0.0       0.00
# 2     Amador       2.90         1.0       7.81         5.0      13.07
# 3      Butte       6.55        17.0       5.83        12.0      11.54
# 4  Calaveras       9.71         3.0       7.79         4.0       7.00
#
#    Counts2020
# 0       144.0
# 1         0.0
# 2         4.0
# 3        26.0
# 4         2.0

# %%
county_opioid_rates["Counts_Growth_2019"] = (county_opioid_rates["Counts2019"] - county_opioid_rates["Counts2018"])/county_opioid_rates["Counts2018"]*100
county_opioid_rates["Counts_Growth_2020"] = (county_opioid_rates["Counts2020"] - county_opioid_rates["Counts2019"])/county_opioid_rates["Counts2019"]*100
county_opioid_rates["Rates_Growth_2019"] = (county_opioid_rates["Rates2019"] - county_opioid_rates["Rates2018"])/county_opioid_rates["Rates2018"]*100
county_opioid_rates["Rates_Growth_2020"] = (county_opioid_rates["Rates2020"] - county_opioid_rates["Rates2019"])/county_opioid_rates["Rates2019"]*100

county_opioid_rates.head()
# Out:
#       County  Rates2018  Counts2018  Rates2019  Counts2019  Rates2020  \
# 0    Alameda       3.10        56.0       5.75       103.0       8.09
# 1     Alpine       0.00         0.0       0.00         0.0       0.00
# 2     Amador       2.90         1.0       7.81         5.0      13.07
# 3      Butte       6.55        17.0       5.83        12.0      11.54
# 4  Calaveras       9.71         3.0       7.79         4.0       7.00
#
#    Counts2020  Counts_Growth_2019  Counts_Growth_2020  Rates_Growth_2019  \
# 0       144.0           83.928571           39.805825          85.483871
# 1         0.0                 NaN                 NaN                NaN
# 2         4.0          400.000000          -20.000000         169.310345
# 3        26.0          -29.411765          116.666667         -10.992366
# 4         2.0           33.333333          -50.000000         -19.773429
#
#    Rates_Growth_2020
# 0          40.695652
# 1                NaN
# 2          67.349552
# 3          97.941681
# 4         -10.141207

# %%
# Fill in null values
county_opioid_rates = county_opioid_rates.fillna(0)

# %%
# Which counties have the highest growth in the opioid-related death counts?
topgrowth = county_opioid_rates[["County","Counts_Growth_2020"]].sort_values(by="Counts_Growth_2020",ascending=True)
topgrowth.plot(kind="barh",x="County",y="Counts_Growth_2020", fontsize =5, figsize =(6,6),ylabel="Growth Rates of Death Counts 2019-2020",title="Growth Rates of Death Counts by County 2019-2020")
# Out:
# <AxesSubplot:title={'center':'Growth Rates of Death Counts by County 2019-2020'}, ylabel='County'>

# %%
# Which counties have the highest growth in the opioid-related death rates?
county_opioid_rates.sort_values(by="Rates_Growth_2020",ascending=False)
# Out:
#              County  Rates2018  Counts2018  Rates2019  Counts2019  Rates2020  \
# 15            Kings       2.76         4.0       1.06         2.0       7.36
# 10            Glenn       4.71         1.0       3.31         1.0      14.87
# 50           Sutter       8.72         8.0       2.50         3.0      10.35
# 51           Tehama       3.52         2.0       1.02         1.0       3.38
# 28           Nevada       6.28         7.0      10.45        10.0      34.09
# 53           Tulare       1.73         7.0       2.52        12.0       8.22
# 46         Siskiyou       3.62         2.0       5.98         2.0      19.37
# 12         Imperial      10.07        16.0       7.02        12.0      19.07
# 39  San Luis Obispo       4.29        13.0       8.12        21.0      20.56
# 27             Napa       3.97         7.0       2.29         3.0       5.20
# 54         Tuolumne       2.52         1.0       1.60         2.0       3.48
# 35   San Bernardino       4.77       106.0       6.10       133.0      12.95
# 38      San Joaquin       3.47        26.0       5.30        39.0      11.10
# 8         El Dorado       4.14         7.0       5.80        10.0      11.72
# 3             Butte       6.55        17.0       5.83        12.0      11.54
# 7         Del Norte       0.00         0.0       4.67         1.0       9.01
# 14             Kern      10.46        92.0      12.79       117.0      24.32
# 29           Orange       7.46       252.0       8.13       272.0      15.45
# 18      Los Angeles       4.57       497.0       6.70       707.0      12.40
# 48           Sonoma       9.23        43.0      13.09        65.0      23.69
# 42      Santa Clara       2.83        60.0       4.12        88.0       7.10
# 56          Ventura      11.14        95.0      10.05        89.0      17.07
# 36        San Diego       7.39       268.0       8.92       314.0      15.14
# 2            Amador       2.90         1.0       7.81         5.0      13.07
# 30           Placer       1.94         8.0       7.39        30.0      12.22
# 37    San Francisco      15.01       147.0      26.96       279.0      44.51
# 32        Riverside       5.74       144.0       9.77       245.0      16.05
# 6      Contra Costa       6.82        82.0       7.86        91.0      12.61
# 49       Stanislaus       5.96        35.0       8.57        46.0      13.50
# 13             Inyo      17.77         3.0      14.47         2.0      22.03
# 20            Marin       3.46         8.0       9.27        22.0      14.06
# 44           Shasta       5.43        10.0      11.11        18.0      16.25
# 9            Fresno       3.52        35.0       4.86        48.0       7.01
# 0           Alameda       3.10        56.0       5.75       103.0       8.09
# 26         Monterey       1.73         8.0       4.46        20.0       5.85
# 23           Merced       7.30        20.0       7.74        20.0       9.98
# 40        San Mateo       4.83        39.0       7.87        65.0      10.06
# 22        Mendocino      13.70        14.0      21.12        18.0      25.84
# 47           Solano       4.02        19.0       7.32        34.0       8.71
# 57             Yolo       2.21         5.0       3.91         9.0       4.04
# 45           Sierra       0.00         0.0       0.00         0.0       0.00
# 1            Alpine       0.00         0.0       0.00         0.0       0.00
# 25             Mono       0.00         0.0       0.00         0.0       0.00
# 55          Unknown       0.00        77.0       0.00         4.0       0.00
# 24            Modoc       0.00         0.0       0.00         0.0       0.00
# 58             Yuba       5.36         4.0      10.82         8.0      10.64
# 11         Humboldt      11.17        16.0      19.05        24.0      18.34
# 5            Colusa       0.00         0.0      15.66         3.0      14.72
# 43       Santa Cruz       8.49        23.0      10.47        29.0       9.65
# 33       Sacramento       4.65        70.0       7.39       119.0       6.81
# 4         Calaveras       9.71         3.0       7.79         4.0       7.00
# 16             Lake      22.70        21.0      32.46        23.0      26.11
# 34       San Benito       3.22         2.0       7.98         5.0       6.33
# 17           Lassen      11.90         4.0      23.47         7.0      18.12
# 41    Santa Barbara       7.09        33.0       5.54        26.0       3.54
# 19           Madera       3.98         6.0       8.33        13.0       4.87
# 31           Plumas      18.11         2.0      11.77         2.0       6.28
# 21         Mariposa       0.00         0.0      23.40         4.0       3.87
# 52          Trinity       7.47         2.0      19.65         2.0       0.00
# 12         171.652422
# 39         153.201970
# 27         127.074236
# 54         117.500000
# 35         112.295082
# 38         109.433962
# 8          102.068966
# 3           97.941681
# 7           92.933619
# 14          90.148554
# 29          90.036900
# 18          85.074627
# 48          80.977846
# 42          72.330097
# 56          69.850746
# 36          69.730942
# 2           67.349552
# 30          65.358593
# 37          65.096439
# 32          64.278403
# 6           60.432570
# 49          57.526254
# 13          52.246026
# 20          51.672060
# 44          46.264626
# 9           44.238683
# 0           40.695652
# 26          31.165919
# 23          28.940568
# 40          27.827192
# 22          22.348485
# 47          18.989071
# 57           3.324808
# 45           0.000000
# 1            0.000000
# 25           0.000000
# 55           0.000000
# 24           0.000000
# 58          -1.663586
# 11          -3.727034
# 5           -6.002554
# 43          -7.831901
# 33          -7.848444
# 4          -10.141207
# 16         -19.562539
# 34         -20.676692
# 17         -22.795058
# 41         -36.101083
# 19         -41.536615
# 31         -46.644010
# 21         -83.461538
# 52        -100.000000

# %%
# Which counties have the highest death rates per 100K residents in 2020
county_opioid_rates.sort_values(by="Rates2020",ascending=False)
# Out:
#              County  Rates2018  Counts2018  Rates2019  Counts2019  Rates2020  \
# 37    San Francisco      15.01       147.0      26.96       279.0      44.51
# 28           Nevada       6.28         7.0      10.45        10.0      34.09
# 16             Lake      22.70        21.0      32.46        23.0      26.11
# 22        Mendocino      13.70        14.0      21.12        18.0      25.84
# 14             Kern      10.46        92.0      12.79       117.0      24.32
# 48           Sonoma       9.23        43.0      13.09        65.0      23.69
# 13             Inyo      17.77         3.0      14.47         2.0      22.03
# 39  San Luis Obispo       4.29        13.0       8.12        21.0      20.56
# 46         Siskiyou       3.62         2.0       5.98         2.0      19.37
# 12         Imperial      10.07        16.0       7.02        12.0      19.07
# 11         Humboldt      11.17        16.0      19.05        24.0      18.34
# 17           Lassen      11.90         4.0      23.47         7.0      18.12
# 56          Ventura      11.14        95.0      10.05        89.0      17.07
# 44           Shasta       5.43        10.0      11.11        18.0      16.25
# 32        Riverside       5.74       144.0       9.77       245.0      16.05
# 29           Orange       7.46       252.0       8.13       272.0      15.45
# 36        San Diego       7.39       268.0       8.92       314.0      15.14
# 10            Glenn       4.71         1.0       3.31         1.0      14.87
# 5            Colusa       0.00         0.0      15.66         3.0      14.72
# 20            Marin       3.46         8.0       9.27        22.0      14.06
# 49       Stanislaus       5.96        35.0       8.57        46.0      13.50
# 2            Amador       2.90         1.0       7.81         5.0      13.07
# 35   San Bernardino       4.77       106.0       6.10       133.0      12.95
# 6      Contra Costa       6.82        82.0       7.86        91.0      12.61
# 18      Los Angeles       4.57       497.0       6.70       707.0      12.40
# 30           Placer       1.94         8.0       7.39        30.0      12.22
# 8         El Dorado       4.14         7.0       5.80        10.0      11.72
# 3             Butte       6.55        17.0       5.83        12.0      11.54
# 38      San Joaquin       3.47        26.0       5.30        39.0      11.10
# 58             Yuba       5.36         4.0      10.82         8.0      10.64
# 50           Sutter       8.72         8.0       2.50         3.0      10.35
# 38        85.0           50.000000          117.948718          52.737752
# 58         9.0          100.000000           12.500000         101.865672
# 50        11.0          -62.500000          266.666667         -71.330275
# 40        81.0           66.666667           24.615385          62.939959
# 23        29.0            0.000000           45.000000           6.027397
# 43        26.0           26.086957          -10.344828          23.321555
# 7          3.0                 inf          200.000000                inf
# 47        39.0           78.947368           14.705882          82.089552
# 53        39.0           71.428571          225.000000          45.664740
# 0        144.0           83.928571           39.805825          85.483871
# 15        10.0          -50.000000          400.000000         -61.594203
# 42       143.0           46.666667           62.500000          45.583039
# 9         71.0           37.142857           47.916667          38.068182
# 4          2.0           33.333333          -50.000000         -19.773429
# 33       107.0           70.000000          -10.084034          58.924731
# 34         4.0          150.000000          -20.000000         147.826087
# 31         1.0            0.000000          -50.000000         -35.008283
# 26        25.0          150.000000           25.000000         157.803468
# 27         8.0          -57.142857          166.666667         -42.317380
# 19         7.0          116.666667          -46.153846         109.296482
# 57        10.0           80.000000           11.111111          76.923077
# 21         1.0                 inf          -75.000000                inf
# 41        16.0          -21.212121          -38.461538         -21.861777
# 54         2.0          100.000000            0.000000         -36.507937
# 51         2.0          -50.000000          100.000000         -71.022727
# 45         0.0            0.000000            0.000000           0.000000
# 52         0.0            0.000000         -100.000000         163.052209
# 24         0.0            0.000000            0.000000           0.000000
# 55       113.0          -94.805195         2725.000000           0.000000
# 25         0.0            0.000000            0.000000           0.000000
# 1          0.0            0.000000            0.000000           0.000000
#
#     Rates_Growth_2020
# 37          65.096439
# 28         226.220096
# 16         -19.562539
# 22          22.348485
# 14          90.148554
# 48          80.977846
# 13          52.246026
# 39         153.201970
# 46         223.913043
# 12         171.652422
# 11          -3.727034
# 17         -22.795058
# 56          69.850746
# 44          46.264626
# 32          64.278403
# 29          90.036900
# 36          69.730942
# 10         349.244713
# 5           -6.002554
# 20          51.672060
# 49          57.526254
# 2           67.349552
# 35         112.295082
# 6           60.432570
# 18          85.074627
# 30          65.358593
# 8          102.068966
# 3           97.941681
# 38         109.433962
# 58          -1.663586
# 50         314.000000
# 40          27.827192
# 23          28.940568
# 43          -7.831901
# 7           92.933619
# 47          18.989071
# 53         226.190476
# 0           40.695652
# 15         594.339623
# 42          72.330097
# 9           44.238683
# 4          -10.141207
# 33          -7.848444
# 34         -20.676692
# 31         -46.644010
# 26          31.165919
# 27         127.074236
# 19         -41.536615
# 57           3.324808
# 21         -83.461538
# 41         -36.101083
# 54         117.500000
# 51         231.372549
# 45           0.000000
# 52        -100.000000
# 24           0.000000
# 55           0.000000
# 25           0.000000
# 1            0.000000

# %% [markdown]
# ### Summary
#
# - In California, both opioid-related death counts and rates have been increasing since 2015. Both death counts and death rates almost doubled from 2019 to 2020, which might indicate the impact of COVID-19 into these numbers.
# - Counties with the highest growth in number of deaths and death rates in 2020 are: Kings, Glenn, Nevada, Siskiyou, Sutter. Notice that the growth rates of these counties from 2018 to 2019 are zero or negative, while they are high in 2020. One possible hypothesis is that the pandemic caused people with opioid addiction to move from bigger counties like Los Angeles, San Francisco, San Bernado to smaller counties, and affected the numbers in those counties.
# - San Francisco, Nevada, Lake, Kern, Sonoma counties had the highest death rates per 100K residents.

# %% [markdown]
# ## Section 2: Relationship between opioid-related deaths vs. healthcare facility and hospital beds distribution in California by county
#
# In this section, we want to answer the following questions:
#
# - Where are the medical facilities with emergency care located in California? How are they distributed?
# - How are hospital beds distributed among different counties in California?
# - Are there any relationships between opioid-related deaths and facility and hospital beds distribution?

# %%
# Load data set
df = pd.read_csv("https://raw.githubusercontent.com/mellanyquiroz/DS4A-TeamProject/master/data/Pre-merging/current-healthcare-facility-listing_cleaned.csv")
df.head()
# Out:
#     OSHPD_ID                                      FACILITY_NAME LICENSE_NUM  \
# 0  106010735                                   ALAMEDA HOSPITAL   140000002
# 1  106010739  ALTA BATES SUMMIT MEDICAL CENTER-ALTA BATES CA...   140000004
# 2  106010776           UCSF BENIOFF CHILDREN'S HOSPITAL OAKLAND   140000015
# 3  106010811                                  FAIRMONT HOSPITAL   140000046
# 4  106010844    ALTA BATES SUMMIT MEDICAL CENTER-HERRICK CAMPUS   140000004
#
#      FACILITY_LEVEL_DESC         DBA_ADDRESS1     DBA_CITY  DBA_ZIP_CODE  \
# 0        Parent Facility     2070 Clinton Ave      Alameda         94501
# 1        Parent Facility       2450 Ashby Ave     Berkeley         94705
# 2        Parent Facility          747 52ND ST      OAKLAND         94609
# 3  Consolidated Facility  15400 Foothill Blvd  San Leandro         94578
# 4  Consolidated Facility      2001 DWIGHT WAY     BERKELEY         94704
#
#    COUNTY_CODE COUNTY_NAME ER_SERVICE_LEVEL_DESC TOTAL_NUMBER_BEDS  \
# 0            1     Alameda     Emergency - Basic               101
# 1            1     Alameda     Emergency - Basic               339
# 2            1     Alameda     Emergency - Basic               215
# 3            1     Alameda                  None               109
# 4            1     Alameda                  None                68
#
#   FACILITY_STATUS_DESC FACILITY_STATUS_DATE LICENSE_TYPE_DESC  \
# 0                 Open           1946-01-01          Hospital
# 1                 Open           1946-01-02          Hospital
# 2                 Open           1946-01-01          Hospital
# 3                 Open           1953-07-01          Hospital
# 4                 Open           1946-01-01          Hospital
#
#          LICENSE_CATEGORY_DESC  LATITUDE   LONGITUDE
# 0  General Acute Care Hospital  37.76266 -122.253991
# 1  General Acute Care Hospital  37.85645 -122.257430
# 2  General Acute Care Hospital  37.83722 -122.267470
# 3  General Acute Care Hospital  37.70648 -122.118190
# 4  General Acute Care Hospital  37.86373 -122.269840

# %% [markdown]
# Below is the data dictionary for this dataframe.
#
# - OSHPD_ID: ID of the facility
# - FACILITY_NAME: Name of the facility
# - LICENSE_NUM: License Number of the facility
# - FACILITY_LEVEL_DESC: Level of the facility
# - DBA_ADDRESS1: Street Address
# - DBA_CITY: City where facility is located
# - DBA_ZIP_CODE: Zip code of the facility
# - COUNTY_CODE: County code where facility is located
# - COUNTY_NAME: Name of County
# - ER_SERVICE_LEVEL_DESC: Level of emergency service that facility provides
# - TOTAL_NUMBER_BEDS: Number of beds in the facility
# - FACILITY_STATUS_DESC: Operating status of the facility
# - FACILITY_STATUS_DATE: Date of the status update
# - LICENSE_TYPE_DESC: Type of license
# - LICENSE_CATEGORY_DESC: Category of license
# - LATITUDE: Latitude of facility location
# - LONGITUDE: Longitude of facility location

# %% [markdown]
# There are a lot of columns which we might not need in our analysis. Let's try to understand each column and drop unnecessary ones.

# %%
# Drop LICENSE_NUM, FACILITY_LEVEL, and COUNTY_CODE
df = df.drop(columns = ['LICENSE_NUM','FACILITY_LEVEL_DESC','COUNTY_CODE'])

# %%
# Check ER_SERVICE_LEVEL_DESC column
df['ER_SERVICE_LEVEL_DESC'].value_counts()
# Out:
# Not Applicable               7901
# Emergency - Basic             293
# None                          113
# Emergency - Standby            30
# Emergency - Comprehensive      11
# Name: ER_SERVICE_LEVEL_DESC, dtype: int64

# %% [markdown]
# Unfortunately, most of the healthcare facilities in California either don't have ER services, or don't have the data related to ER services.

# %%
# Replace None with Not Applicable for consistency
df['ER_SERVICE_LEVEL_DESC'] = df['ER_SERVICE_LEVEL_DESC'].replace('None','Not Applicable')
df['ER_SERVICE_LEVEL_DESC'].value_counts()
# Out:
# Not Applicable               8014
# Emergency - Basic             293
# Emergency - Standby            30
# Emergency - Comprehensive      11
# Name: ER_SERVICE_LEVEL_DESC, dtype: int64

# %%
# Check License type column
df['LICENSE_TYPE_DESC'].value_counts()
# Out:
# Home Health Agency/Hospice    4338
# Clinic                        2105
# Long Term Care Facility       1378
# Hospital                       527
# Name: LICENSE_TYPE_DESC, dtype: int64

# %%
# Check License Category column
df['LICENSE_CATEGORY_DESC'].value_counts()
# Out:
# Home Health Agency                   2571
# Hospice                              1767
# Community Clinic                     1332
# Skilled Nursing Facility             1098
# Chronic Dialysis Clinic               652
# General Acute Care Hospital           447
# Congregate Living Health Facility     256
# Free Clinic                            46
# Acute Psychiatric Hospital             39
# Psychiatric Health Facility            34
# Surgical Clinic                        32
# Psychology Clinic                      19
# Hospice Facility                       14
# Rehabilitation Clinic                  12
# Alternative Birthing Center            12
# ICF/Dev. Disabled                      10
# Chemical Dep. Recovery Hospital         7
# Name: LICENSE_CATEGORY_DESC, dtype: int64

# %%
df['COUNTY_NAME'] = df['COUNTY_NAME'].astype('category')
df['TOTAL_NUMBER_BEDS'] = df['TOTAL_NUMBER_BEDS'].str.replace(",","").astype('int64')

# %% [markdown]
# ### Counties without ER or ER data

# %%
# Subset the dataframe to choose facilities without ER service
df_noer = df[df["ER_SERVICE_LEVEL_DESC"] == 'Not Applicable']
df_noer.head()
# Out:
#      OSHPD_ID                                     FACILITY_NAME  \
# 3   106010811                                 FAIRMONT HOSPITAL
# 4   106010844   ALTA BATES SUMMIT MEDICAL CENTER-HERRICK CAMPUS
# 6   106010887         KINDRED HOSPITAL - SAN FRANCISCO BAY AREA
# 9   106010983                          VALLEY MEMORIAL HOSPITAL
# 12  106013626  ALTA BATES SUMMIT MEDICAL CENTER - SUMMIT CAMPUS
#
#            DBA_ADDRESS1     DBA_CITY  DBA_ZIP_CODE COUNTY_NAME  \
# 3   15400 Foothill Blvd  San Leandro         94578     Alameda
# 4       2001 DWIGHT WAY     BERKELEY         94704     Alameda
# 6      2800 BENEDICT DR  SAN LEANDRO         94577     Alameda
# 9   1111 E STANLEY BLVD    LIVERMORE         94550     Alameda
# 12       3100 SUMMIT ST      OAKLAND         94609     Alameda
#
#    ER_SERVICE_LEVEL_DESC  TOTAL_NUMBER_BEDS FACILITY_STATUS_DESC  \
# 3         Not Applicable                109                 Open
# 4         Not Applicable                 68                 Open
# 6         Not Applicable                 99                 Open
# 9         Not Applicable                 75                 Open
# 12        Not Applicable                 58                 Open
#
#    FACILITY_STATUS_DATE LICENSE_TYPE_DESC        LICENSE_CATEGORY_DESC  \
# 3            1953-07-01          Hospital  General Acute Care Hospital
# 4            1946-01-01          Hospital  General Acute Care Hospital
# 6            1962-11-13          Hospital  General Acute Care Hospital
# 9            1969-10-19          Hospital  General Acute Care Hospital
# 12           1946-01-01          Hospital  General Acute Care Hospital
#
#     LATITUDE  LONGITUDE
# 3   37.70648 -122.11819
# 4   37.86373 -122.26984
# 6   37.71621 -122.13119
# 9   37.67870 -121.78252
# 12  37.81994 -122.26430

# %%
# Count number of facility without ER by county
noer_county = df_noer.groupby('COUNTY_NAME')['OSHPD_ID'].count().reset_index().sort_values(by = 'OSHPD_ID', ascending = False)
noer_county = noer_county.rename(columns = {"OSHPD_ID":"COUNT_NOER_FAC"})
noer_county.head()
# Out:
#        COUNTY_NAME  COUNT_NOER_FAC
# 17     Los Angeles            3708
# 34  San Bernardino             464
# 28          Orange             456
# 35       San Diego             403
# 0          Alameda             327

# %%
# Count number of total hospital beds by county
totalbeds = df.groupby('COUNTY_NAME')['TOTAL_NUMBER_BEDS'].sum().reset_index().sort_values(by = 'TOTAL_NUMBER_BEDS', ascending = False)
totalbeds.head()
# Out:
#        COUNTY_NAME  TOTAL_NUMBER_BEDS
# 17     Los Angeles              65542
# 35       San Diego              16456
# 28          Orange              14362
# 34  San Bernardino              10940
# 41     Santa Clara               9263

# %%
# Count total healthcare facilities by county
totalfacility = df.groupby('COUNTY_NAME')['OSHPD_ID'].count().reset_index().sort_values(by = 'OSHPD_ID', ascending = False)
totalfacility = totalfacility.rename(columns = {"OSHPD_ID":"TOTAL_FAC"})
totalfacility.head()
# Out:
#        COUNTY_NAME  TOTAL_FAC
# 17     Los Angeles       3781
# 34  San Bernardino        483
# 28          Orange        482
# 35       San Diego        421
# 0          Alameda        340

# %%
# Combine all above dataframes
df_by_county_merged = totalfacility.set_index("COUNTY_NAME").join(totalbeds.set_index("COUNTY_NAME"))
df_by_county_merged = df_by_county_merged.join(noer_county.set_index("COUNTY_NAME"))
df_by_county_merged.head()
# Out:
#                 TOTAL_FAC  TOTAL_NUMBER_BEDS  COUNT_NOER_FAC
# COUNTY_NAME
# Los Angeles          3781              65542            3708
# San Bernardino        483              10940             464
# Orange                482              14362             456
# San Diego             421              16456             403
# Alameda               340               9074             327

# %% [markdown]
# ### Explore Emergency Care facilities

# %%
# Subset the dataframe to choose facilities with ER service only
df_emergency = df[df['ER_SERVICE_LEVEL_DESC'] != 'Not Applicable']
df_emergency.head()
# Out:
#     OSHPD_ID                                      FACILITY_NAME  \
# 0  106010735                                   ALAMEDA HOSPITAL
# 1  106010739  ALTA BATES SUMMIT MEDICAL CENTER-ALTA BATES CA...
# 2  106010776           UCSF BENIOFF CHILDREN'S HOSPITAL OAKLAND
# 5  106010846                                  HIGHLAND HOSPITAL
# 7  106010937                   ALTA BATES SUMMIT MEDICAL CENTER
#
#         DBA_ADDRESS1  DBA_CITY  DBA_ZIP_CODE COUNTY_NAME  \
# 0   2070 Clinton Ave   Alameda         94501     Alameda
# 1     2450 Ashby Ave  Berkeley         94705     Alameda
# 2        747 52ND ST   OAKLAND         94609     Alameda
# 5     1411 E 31st St   Oakland         94602     Alameda
# 7  350 HAWTHORNE AVE   OAKLAND         94609     Alameda
#
#   ER_SERVICE_LEVEL_DESC  TOTAL_NUMBER_BEDS FACILITY_STATUS_DESC  \
# 0     Emergency - Basic                101                 Open
# 1     Emergency - Basic                339                 Open
# 2     Emergency - Basic                215                 Open
# 5     Emergency - Basic                249                 Open
# 7     Emergency - Basic                403                 Open
#
#   FACILITY_STATUS_DATE LICENSE_TYPE_DESC        LICENSE_CATEGORY_DESC  \
# 0           1946-01-01          Hospital  General Acute Care Hospital
# 1           1946-01-02          Hospital  General Acute Care Hospital
# 2           1946-01-01          Hospital  General Acute Care Hospital
# 5           1953-07-01          Hospital  General Acute Care Hospital
# 7           1946-01-01          Hospital  General Acute Care Hospital
#
#    LATITUDE   LONGITUDE
# 0  37.76266 -122.253991
# 1  37.85645 -122.257430
# 2  37.83722 -122.267470
# 5  37.79925 -122.231380
# 7  37.82106 -122.262570

# %%
# Check facility status
df_emergency['FACILITY_STATUS_DESC'].value_counts()
# Out:
# Open        333
# Suspense      1
# Name: FACILITY_STATUS_DESC, dtype: int64

# %%
# Which facility was suspended? Maybe we could drop it
df_emergency[df_emergency['FACILITY_STATUS_DESC'] == 'Suspense']
# Out:
#       OSHPD_ID           FACILITY_NAME         DBA_ADDRESS1     DBA_CITY  \
# 150  106190534  OLYMPIA MEDICAL CENTER  5900 W Olympic Blvd  Los Angeles
#
#      DBA_ZIP_CODE  COUNTY_NAME ER_SERVICE_LEVEL_DESC  TOTAL_NUMBER_BEDS  \
# 150         90036  Los Angeles     Emergency - Basic                204
#
#     FACILITY_STATUS_DESC FACILITY_STATUS_DATE LICENSE_TYPE_DESC  \
# 150             Suspense           2021-04-01          Hospital
#
#            LICENSE_CATEGORY_DESC  LATITUDE  LONGITUDE
# 150  General Acute Care Hospital  34.05754 -118.36008

# %%
# Choose dataframe with status 'Open' only
df_emergency = df_emergency[df_emergency['FACILITY_STATUS_DESC'] == 'Open']

# %% [markdown]
# #### Where are the medical facilities with emergency care located in California?

# %%
# Count number of emergency facility by county
emergency_county = df_emergency.groupby('COUNTY_NAME')['OSHPD_ID'].count().reset_index().sort_values(by = 'OSHPD_ID', ascending = False)
emergency_county = emergency_county.rename(columns = {"OSHPD_ID":"COUNT_ER_FAC"})

# %%
emergency_county.head()
# Out:
#        COUNTY_NAME  COUNT_ER_FAC
# 17     Los Angeles            72
# 28          Orange            26
# 34  San Bernardino            19
# 35       San Diego            18
# 31       Riverside            17

# %%
# What about number of hospital beds by county?
beds_by_county = df_emergency.groupby('COUNTY_NAME')['TOTAL_NUMBER_BEDS'].sum().reset_index().sort_values(by = 'TOTAL_NUMBER_BEDS', ascending = False)
beds_by_county.head()
# Out:
#        COUNTY_NAME  TOTAL_NUMBER_BEDS
# 17     Los Angeles              20947
# 35       San Diego               6260
# 28          Orange               5968
# 34  San Bernardino               4079
# 31       Riverside               3512

# %%
# Merge these 2 tables by County name
df_by_county = emergency_county.set_index('COUNTY_NAME').join(beds_by_county.set_index('COUNTY_NAME'))
df_by_county = df_by_county.rename(columns={"TOTAL_NUMBER_BEDS":"ER_BEDS"})
df_by_county.head()
# Out:
#                 COUNT_ER_FAC  ER_BEDS
# COUNTY_NAME
# Los Angeles               72    20947
# Orange                    26     5968
# San Bernardino            19     4079
# San Diego                 18     6260
# Riverside                 17     3512

# %%
# Join with df_by_county_merged
df_by_county_merged = df_by_county_merged.join(df_by_county)
df_by_county_merged.head()
# Out:
#                 TOTAL_FAC  TOTAL_NUMBER_BEDS  COUNT_NOER_FAC  COUNT_ER_FAC  \
# COUNTY_NAME
# Los Angeles          3781              65542            3708            72
# San Bernardino        483              10940             464            19
# Orange                482              14362             456            26
# San Diego             421              16456             403            18
# Alameda               340               9074             327            13
#
#                 ER_BEDS
# COUNTY_NAME
# Los Angeles       20947
# San Bernardino     4079
# Orange             5968
# San Diego          6260
# Alameda            2894

# %%
# Prepare to join with population and area data
df_by_county_merged = df_by_county_merged.reset_index()
df_by_county_merged["COUNTY_NAME"] = df_by_county_merged["COUNTY_NAME"].str.strip()
df_by_county_merged.head()
# Out:
#    index     COUNTY_NAME  TOTAL_FAC  TOTAL_NUMBER_BEDS  COUNT_NOER_FAC  \
# 0      0     Los Angeles       3781              65542            3708
# 1      1  San Bernardino        483              10940             464
# 2      2          Orange        482              14362             456
# 3      3       San Diego        421              16456             403
# 4      4         Alameda        340               9074             327
#
#    COUNT_ER_FAC  ER_BEDS
# 0            72    20947
# 1            19     4079
# 2            26     5968
# 3            18     6260
# 4            13     2894

# %% [markdown]
# ### Add population by county data
# Until this point, we've only looked at absolute number of ER facilities and hospital beds. In order to compare these number among counties, we need to add population data.

# %%
# load dataframe
pop_df = pd.read_csv("https://raw.githubusercontent.com/mellanyquiroz/DS4A-TeamProject/master/data/Pre-merging/population_by_county_cleaned2021.csv")
pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  58 non-null     int64
#  1   CTYNAME     58 non-null     object
#  2   pop2021     58 non-null     int64
#  3   GrowthRate  58 non-null     float64
#  4   popDensity  58 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.4+ KB

# %%
pop_df.head()
# Out:
#    Unnamed: 0          CTYNAME  pop2021  GrowthRate  popDensity
# 0           0     Los Angeles   9969510      1.4889   2456.6933
# 1           1       San Diego   3347270      7.8648    795.7052
# 2           2          Orange   3175130      5.3052   4015.0980
# 3           3       Riverside   2520060     14.4660    349.6980
# 4           4  San Bernardino   2206750      8.1290    110.0236

# %%
# Calculate County Area data
pop_df["COUNTY_AREA"] = pop_df["pop2021"]/pop_df["popDensity"]

# Prepare to join
pop_df["pop2021"] = pop_df["pop2021"].astype(int)
pop_df["CTYNAME"] = pop_df["CTYNAME"].astype(str)
pop_df["CTYNAME"] = pop_df["CTYNAME"].str.strip()

pop_df = pop_df.drop(columns= ["Unnamed: 0","GrowthRate","popDensity"])
pop_df= pop_df.set_index("CTYNAME")

# %%
# Merge with df_by_county
county_merged = df_by_county_merged.set_index("COUNTY_NAME").join(pop_df)
county_merged
# Out:
#                  index  TOTAL_FAC  TOTAL_NUMBER_BEDS  COUNT_NOER_FAC  \
# COUNTY_NAME
# Los Angeles          0       3781              65542            3708
# San Bernardino       1        483              10940             464
# Orange               2        482              14362             456
# San Diego            3        421              16456             403
# Alameda              4        340               9074             327
# Riverside            5        300               9170             283
# Ventura              6        238               3456             230
# Sacramento           7        211               7433             203
# Santa Clara          8        210               9263             199
# Fresno               9        182               6579             175
# Kern                10        144               3751             134
# Contra Costa        11        140               4674             132
# San Joaquin         12        110               3882             103
# San Francisco       13        102               5334              92
# San Mateo           14         97               2879              90
# Stanislaus          15         91               3500              86
# Sonoma              16         80               2399              74
# Santa Barbara       17         78               2248              73
# Tulare              18         75               2966              72
# San Luis Obispo     19         69               2554              65
# Monterey            20         67               1760              63
# Solano              21         56               1621              51
# Marin               22         45               1588              42
# Merced              23         44               1021              42
# Butte               24         44               1387              41
# Shasta              25         41               1660              38
# Placer              26         41               1960              38
# Humboldt            27         35                760              31
# Mendocino           28         28                488              25
# Santa Cruz          29         27               1097              25
# Napa                30         24               2518              22
# Imperial            31         24                521              22
# Madera              32         22                862              20
# Yolo                33         21                739              19
# Sutter              34         21                495              21
# Kings               35         17                498              16
# El Dorado           36         17                518              15
# Nevada              37         16                566              14
# Lake                38         15                332              13
# Siskiyou            39         13                126              11
# Tuolumne            40         12                362              11
# Yuba                41         11                307              10
# Tehama              42          9                205               8
# Del Norte           43          8                148               7
# Lassen              44          7                121               6
# San Benito          45          6                144               5
# Colusa              46          6                147               5
# Inyo                47          5                161               3
# Glenn               48          5                123               4
# Amador              49          5                251               4
# Mariposa            50          5                 34               4
# Calaveras           51          5                124               4
# Plumas              52          4                 78               1
# Trinity             53          3                 48               2
# Sierra              54          2                 39               2
# Modoc               55          2                105               0
# Mono                56          1                 17               0
#
#                  COUNT_ER_FAC  ER_BEDS  pop2021   COUNTY_AREA
# COUNTY_NAME
# Los Angeles                72    20947  9969510   4058.101188
# San Bernardino             19     4079  2206750  20057.060485
# Orange                     26     5968  3175130    790.797634
# San Diego                  18     6260  3347270   4206.671013
# Alameda                    13     2894  1680480    739.092592
# Riverside                  17     3512  2520060   7206.389513
# Ventura                     8     1417   841734   1843.012829
# Sacramento                  8     2935  1578680    964.940204
# Santa Clara                11     3492  1918880   1290.216648
# Fresno                      7     1732  1013400   5958.820984
# Kern                       10     1514   913090   8131.976178
# Contra Costa                8     1666  1159540    722.742800
# San Joaquin                 7     1152   781462   1391.375969
# San Francisco              10     2757   883255     46.894305
# San Mateo                   7     1367   762357    448.474181
# Stanislaus                  5     1209   555728   1494.550557
# Sonoma                      6      713   485722   1575.838114
# Santa Barbara               5      925   447937   2735.120652
# Tulare                      3      710   469407   4824.262369
# San Luis Obispo             4      449   282625   3300.614285
# Monterey                    4      766   434283   3280.605897
# Solano                      5      698   451479    821.772019
# Marin                       3      490   257154    520.492492
# Merced                      2      224   284738   1934.967405
# Butte                       3      467   196880   1636.463682
# Shasta                      3      607   180822   3775.383652
# Placer                      3      798   410327   1407.084684
# Humboldt                    4      268   134186   3567.970007
# Mendocino                   3      118    85445   3506.356541
# Santa Cruz                  2      328   271957    445.163184
# Napa                        2      351   135654    748.367322
# Imperial                    2      268   180599   4176.616829
# Madera                      2      464   158217   2137.097210
# Yolo                        2      153   221264   1014.766731
# Sutter                      0        0    98217    602.410821
# Kings                       1      173   156056   1389.420864
# El Dorado                   2      236   197037   1707.901418
# Nevada                      2      174   100249    957.779878
# Lake                        2       62    64524   1256.487001
# Siskiyou                    2       61    43517   6277.878762
# Tuolumne                    1       72    54660   2220.903964
# Yuba                        1      221    80890    632.042994
# Tehama                      1       76    67216   2949.713217
# Del Norte                   1       49    27956   1006.292025
# Lassen                      1       25    30483   4541.161398
# San Benito                  1       82    65490   1388.709236
# Colusa                      1       48    21805   1150.726427
# Inyo                        2       62    18225  10180.995475
# Glenn                       1       47    29245   1313.945025
# Amador                      1       52    40446    594.577272
# Mariposa                    1       34    16799   1448.814144
# Calaveras                   1       25    46319   1020.013125
# Plumas                      3       78    18939   2553.045213
# Trinity                     1       48    11721   3179.266010
# Sierra                      0        0     3021    953.177258
# Modoc                       2      105     8923   3915.485541
# Mono                        1       17    14526   3048.926390

# %%
# Calculate healthcare availability metrics per 100K residents
county_merged["TOTALFAC_PER_POP"] = county_merged["TOTAL_FAC"]/county_merged["pop2021"]*100000
county_merged["TOTALBEDS_PER_POP"] = county_merged["TOTAL_NUMBER_BEDS"]/county_merged["pop2021"]*100000
county_merged["ERFAC_PER_POP"] = county_merged["COUNT_ER_FAC"]/county_merged["pop2021"]*100000
county_merged["ERBEDS_PER_POP"] = county_merged["ER_BEDS"]/county_merged["pop2021"]*100000
county_merged["ERFAC_PER_AREA"] =  county_merged["COUNT_ER_FAC"]/county_merged["COUNTY_AREA"]

# %%
county_merged.head()
# Out:
#                 index  TOTAL_FAC  TOTAL_NUMBER_BEDS  COUNT_NOER_FAC  \
# COUNTY_NAME
# Los Angeles         0       3781              65542            3708
# San Bernardino      1        483              10940             464
# Orange              2        482              14362             456
# San Diego           3        421              16456             403
# Alameda             4        340               9074             327
#
#                 COUNT_ER_FAC  ER_BEDS  pop2021   COUNTY_AREA  \
# COUNTY_NAME
# Los Angeles               72    20947  9969510   4058.101188
# San Bernardino            19     4079  2206750  20057.060485
# Orange                    26     5968  3175130    790.797634
# San Diego                 18     6260  3347270   4206.671013
# Alameda                   13     2894  1680480    739.092592
#
#                 TOTALFAC_PER_POP  TOTALBEDS_PER_POP  ERFAC_PER_POP  \
# COUNTY_NAME
# Los Angeles            37.925635         657.424487       0.722202
# San Bernardino         21.887391         495.751671       0.860995
# Orange                 15.180481         452.327936       0.818864
# San Diego              12.577414         491.624518       0.537752
# Alameda                20.232315         539.964772       0.773588
#
#                 ERBEDS_PER_POP  ERFAC_PER_AREA
# COUNTY_NAME
# Los Angeles         210.110627        0.017742
# San Bernardino      184.841962        0.000947
# Orange              187.960808        0.032878
# San Diego           187.018077        0.004279
# Alameda             172.212701        0.017589

# %% [markdown]
# ## Merge with opioid-related death data
#
# By merging these 2 data sets, we can answer these following questions:
# - How are death counts and death rates distributed visually on a California map?
# - Are there any correlation between the distribution of ER facility or distribution of hospital beds, and opioid-related deaths?

# %%
# Merge with opioid-related deaths data
county_sum = county_merged.merge(county_opioid_rates,left_on="COUNTY_NAME",right_on="County")
county_sum
# Out:
#     index  TOTAL_FAC  TOTAL_NUMBER_BEDS  COUNT_NOER_FAC  COUNT_ER_FAC  \
# 0       0       3781              65542            3708            72
# 1       1        483              10940             464            19
# 2       2        482              14362             456            26
# 3       3        421              16456             403            18
# 4       4        340               9074             327            13
# 5       5        300               9170             283            17
# 6       6        238               3456             230             8
# 7       7        211               7433             203             8
# 8       8        210               9263             199            11
# 9       9        182               6579             175             7
# 10     10        144               3751             134            10
# 11     11        140               4674             132             8
# 12     12        110               3882             103             7
# 13     13        102               5334              92            10
# 14     14         97               2879              90             7
# 15     15         91               3500              86             5
# 16     16         80               2399              74             6
# 17     17         78               2248              73             5
# 18     18         75               2966              72             3
# 19     19         69               2554              65             4
# 20     20         67               1760              63             4
# 21     21         56               1621              51             5
# 22     22         45               1588              42             3
# 23     23         44               1021              42             2
# 24     24         44               1387              41             3
# 25     25         41               1660              38             3
# 26     26         41               1960              38             3
# 27     27         35                760              31             4
# 28     28         28                488              25             3
# 29     29         27               1097              25             2
# 30     30         24               2518              22             2
# 31     31         24                521              22             2
# 32     32         22                862              20             2
# 33     33         21                739              19             2
# 34     34         21                495              21             0
# 35     35         17                498              16             1
# 36     36         17                518              15             2
# 37     37         16                566              14             2
# 38     38         15                332              13             2
# 39     39         13                126              11             2
# 40     40         12                362              11             1
# 41     41         11                307              10             1
# 42     42          9                205               8             1
# 43     43          8                148               7             1
# 44     44          7                121               6             1
# 45     45          6                144               5             1
# 46     46          6                147               5             1
# 47     47          5                161               3             2
# 48     48          5                123               4             1
# 49     49          5                251               4             1
# 50     50          5                 34               4             1
# 51     51          5                124               4             1
# 52     52          4                 78               1             3
# 53     53          3                 48               2             1
# 50       34    16799   1448.814144         29.763676         202.393000  ...
# 51       25    46319   1020.013125         10.794706         267.708716  ...
# 52       78    18939   2553.045213         21.120439         411.848566  ...
# 53       48    11721   3179.266010         25.595086         409.521372  ...
# 54        0     3021    953.177258         66.203244        1290.963257  ...
# 55      105     8923   3915.485541         22.413986        1176.734282  ...
# 56       17    14526   3048.926390          6.884208         117.031530  ...
#
#     Rates2018  Counts2018  Rates2019 Counts2019  Rates2020  Counts2020  \
# 0        4.57       497.0       6.70      707.0      12.40      1300.0
# 1        4.77       106.0       6.10      133.0      12.95       288.0
# 2        7.46       252.0       8.13      272.0      15.45       503.0
# 3        7.39       268.0       8.92      314.0      15.14       528.0
# 4        3.10        56.0       5.75      103.0       8.09       144.0
# 5        5.74       144.0       9.77      245.0      16.05       400.0
# 6       11.14        95.0      10.05       89.0      17.07       141.0
# 7        4.65        70.0       7.39      119.0       6.81       107.0
# 8        2.83        60.0       4.12       88.0       7.10       143.0
# 9        3.52        35.0       4.86       48.0       7.01        71.0
# 10      10.46        92.0      12.79      117.0      24.32       222.0
# 11       6.82        82.0       7.86       91.0      12.61       144.0
# 12       3.47        26.0       5.30       39.0      11.10        85.0
# 13      15.01       147.0      26.96      279.0      44.51       443.0
# 14       4.83        39.0       7.87       65.0      10.06        81.0
# 15       5.96        35.0       8.57       46.0      13.50        74.0
# 16       9.23        43.0      13.09       65.0      23.69       111.0
# 17       7.09        33.0       5.54       26.0       3.54        16.0
# 18       1.73         7.0       2.52       12.0       8.22        39.0
# 19       4.29        13.0       8.12       21.0      20.56        57.0
# 20       1.73         8.0       4.46       20.0       5.85        25.0
# 21       4.02        19.0       7.32       34.0       8.71        39.0
# 22       3.46         8.0       9.27       22.0      14.06        33.0
# 23       7.30        20.0       7.74       20.0       9.98        29.0
# 24       6.55        17.0       5.83       12.0      11.54        26.0
# 25       5.43        10.0      11.11       18.0      16.25        27.0
# 26       1.94         8.0       7.39       30.0      12.22        45.0
# 27      11.17        16.0      19.05       24.0      18.34        24.0
# 28      13.70        14.0      21.12       18.0      25.84        20.0
# 29       8.49        23.0      10.47       29.0       9.65        26.0
# 30       3.97         7.0       2.29        3.0       5.20         8.0
# 31      10.07        16.0       7.02       12.0      19.07        32.0
# 32       3.98         6.0       8.33       13.0       4.87         7.0
# 33       2.21         5.0       3.91        9.0       4.04        10.0
# 34       8.72         8.0       2.50        3.0      10.35        11.0
# 35       2.76         4.0       1.06        2.0       7.36        10.0
# 36       4.14         7.0       5.80       10.0      11.72        22.0
# 37       6.28         7.0      10.45       10.0      34.09        30.0
# 38      22.70        21.0      32.46       23.0      26.11        17.0
# 39       3.62         2.0       5.98        2.0      19.37         7.0
# 40       2.52         1.0       1.60        2.0       3.48         2.0
# 41       5.36         4.0      10.82        8.0      10.64         9.0
# 42       3.52         2.0       1.02        1.0       3.38         2.0
# 43       0.00         0.0       4.67        1.0       9.01         3.0
# 44      11.90         4.0      23.47        7.0      18.12         7.0
# 2           90.036900
# 3           69.730942
# 4           40.695652
# 5           64.278403
# 6           69.850746
# 7           -7.848444
# 8           72.330097
# 9           44.238683
# 10          90.148554
# 11          60.432570
# 12         109.433962
# 13          65.096439
# 14          27.827192
# 15          57.526254
# 16          80.977846
# 17         -36.101083
# 18         226.190476
# 19         153.201970
# 20          31.165919
# 21          18.989071
# 22          51.672060
# 23          28.940568
# 24          97.941681
# 25          46.264626
# 26          65.358593
# 27          -3.727034
# 28          22.348485
# 29          -7.831901
# 30         127.074236
# 31         171.652422
# 32         -41.536615
# 33           3.324808
# 34         314.000000
# 35         594.339623
# 36         102.068966
# 37         226.220096
# 38         -19.562539
# 39         223.913043
# 40         117.500000
# 41          -1.663586
# 42         231.372549
# 43          92.933619
# 44         -22.795058
# 45         -20.676692
# 46          -6.002554
# 47          52.246026
# 48         349.244713
# 49          67.349552
# 50         -83.461538
# 51         -10.141207
# 52         -46.644010
# 53        -100.000000
# 54           0.000000
# 55           0.000000
# 56           0.000000
#
# [57 rows x 24 columns]

# %%
county_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 0 to 56
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               57 non-null     int64
#  1   TOTAL_FAC           57 non-null     int64
#  2   TOTAL_NUMBER_BEDS   57 non-null     int64
#  3   COUNT_NOER_FAC      57 non-null     int64
#  4   COUNT_ER_FAC        57 non-null     int64
#  5   ER_BEDS             57 non-null     int64
#  6   pop2021             57 non-null     int64
#  7   COUNTY_AREA         57 non-null     float64
#  8   TOTALFAC_PER_POP    57 non-null     float64
#  9   TOTALBEDS_PER_POP   57 non-null     float64
#  10  ERFAC_PER_POP       57 non-null     float64
#  11  ERBEDS_PER_POP      57 non-null     float64
#  12  ERFAC_PER_AREA      57 non-null     float64
#  13  County              57 non-null     object
#  14  Rates2018           57 non-null     float64
#  15  Counts2018          57 non-null     float64
#  16  Rates2019           57 non-null     float64
#  17  Counts2019          57 non-null     float64
#  18  Rates2020           57 non-null     float64
#  19  Counts2020          57 non-null     float64
#  20  Counts_Growth_2019  57 non-null     float64
#  21  Counts_Growth_2020  57 non-null     float64
#  22  Rates_Growth_2019   57 non-null     float64
#  23  Rates_Growth_2020   57 non-null     float64
# dtypes: float64(16), int64(7), object(1)
# memory usage: 11.1+ KB

# %%
# Clean the merged dataset: remove unnecessary columns and rename columns
county_sum = county_sum.drop(columns=["index","pop2021","COUNTY_AREA","Rates2018","Counts2018","Rates_Growth_2019","Rates_Growth_2020"])
to_renamed = {
    "County":"COUNTY",
    "Rates2019":"DEATHRATES19",
    "Counts2019":"DEATHCOUNTS19",
    "Rates2020":"DEATHRATES20",
    "Counts2020":"DEATHCOUNTS20",
    "Counts_Growth_2019":"COUNTS_GR19",
    "Counts_Growth_2020":"COUNTS_GR20"}
county_sum = county_sum.rename(columns=to_renamed)

county_sum.head()
# Out:
#    TOTAL_FAC  TOTAL_NUMBER_BEDS  COUNT_NOER_FAC  COUNT_ER_FAC  ER_BEDS  \
# 0       3781              65542            3708            72    20947
# 1        483              10940             464            19     4079
# 2        482              14362             456            26     5968
# 3        421              16456             403            18     6260
# 4        340               9074             327            13     2894
#
#    TOTALFAC_PER_POP  TOTALBEDS_PER_POP  ERFAC_PER_POP  ERBEDS_PER_POP  \
# 0         37.925635         657.424487       0.722202      210.110627
# 1         21.887391         495.751671       0.860995      184.841962
# 2         15.180481         452.327936       0.818864      187.960808
# 3         12.577414         491.624518       0.537752      187.018077
# 4         20.232315         539.964772       0.773588      172.212701
#
#    ERFAC_PER_AREA          COUNTY  DEATHRATES19  DEATHCOUNTS19  DEATHRATES20  \
# 0        0.017742     Los Angeles          6.70          707.0         12.40
# 1        0.000947  San Bernardino          6.10          133.0         12.95
# 2        0.032878          Orange          8.13          272.0         15.45
# 3        0.004279       San Diego          8.92          314.0         15.14
# 4        0.017589         Alameda          5.75          103.0          8.09
#
#    DEATHCOUNTS20  COUNTS_GR19  COUNTS_GR20
# 0         1300.0    42.253521    83.875530
# 1          288.0    25.471698   116.541353
# 2          503.0     7.936508    84.926471
# 3          528.0    17.164179    68.152866
# 4          144.0    83.928571    39.805825

# %%
county_sum.replace([np.inf, -np.inf], np.nan, inplace=True)
county_sum.fillna(0)
county_sum.set_index("COUNTY")
# Out:
#                  TOTAL_FAC  TOTAL_NUMBER_BEDS  COUNT_NOER_FAC  COUNT_ER_FAC  \
# COUNTY
# Los Angeles           3781              65542            3708            72
# San Bernardino         483              10940             464            19
# Orange                 482              14362             456            26
# San Diego              421              16456             403            18
# Alameda                340               9074             327            13
# Riverside              300               9170             283            17
# Ventura                238               3456             230             8
# Sacramento             211               7433             203             8
# Santa Clara            210               9263             199            11
# Fresno                 182               6579             175             7
# Kern                   144               3751             134            10
# Contra Costa           140               4674             132             8
# San Joaquin            110               3882             103             7
# San Francisco          102               5334              92            10
# San Mateo               97               2879              90             7
# Stanislaus              91               3500              86             5
# Sonoma                  80               2399              74             6
# Santa Barbara           78               2248              73             5
# Tulare                  75               2966              72             3
# San Luis Obispo         69               2554              65             4
# Monterey                67               1760              63             4
# Solano                  56               1621              51             5
# Marin                   45               1588              42             3
# Merced                  44               1021              42             2
# Butte                   44               1387              41             3
# Shasta                  41               1660              38             3
# Placer                  41               1960              38             3
# Humboldt                35                760              31             4
# Mendocino               28                488              25             3
# Santa Cruz              27               1097              25             2
# Napa                    24               2518              22             2
# Imperial                24                521              22             2
# Madera                  22                862              20             2
# Yolo                    21                739              19             2
# Sutter                  21                495              21             0
# Kings                   17                498              16             1
# El Dorado               17                518              15             2
# Nevada                  16                566              14             2
# Lake                    15                332              13             2
# Siskiyou                13                126              11             2
# Tuolumne                12                362              11             1
# Yuba                    11                307              10             1
# Tehama                   9                205               8             1
# Del Norte                8                148               7             1
# Lassen                   7                121               6             1
# San Benito               6                144               5             1
# Colusa                   6                147               5             1
# Inyo                     5                161               3             2
# Glenn                    5                123               4             1
# Amador                   5                251               4             1
# Mariposa                 5                 34               4             1
# Calaveras                5                124               4             1
# Plumas                   4                 78               1             3
# Trinity                  3                 48               2             1
# San Bernardino          12.95          288.0    25.471698   116.541353
# Orange                  15.45          503.0     7.936508    84.926471
# San Diego               15.14          528.0    17.164179    68.152866
# Alameda                  8.09          144.0    83.928571    39.805825
# Riverside               16.05          400.0    70.138889    63.265306
# Ventura                 17.07          141.0    -6.315789    58.426966
# Sacramento               6.81          107.0    70.000000   -10.084034
# Santa Clara              7.10          143.0    46.666667    62.500000
# Fresno                   7.01           71.0    37.142857    47.916667
# Kern                    24.32          222.0    27.173913    89.743590
# Contra Costa            12.61          144.0    10.975610    58.241758
# San Joaquin             11.10           85.0    50.000000   117.948718
# San Francisco           44.51          443.0    89.795918    58.781362
# San Mateo               10.06           81.0    66.666667    24.615385
# Stanislaus              13.50           74.0    31.428571    60.869565
# Sonoma                  23.69          111.0    51.162791    70.769231
# Santa Barbara            3.54           16.0   -21.212121   -38.461538
# Tulare                   8.22           39.0    71.428571   225.000000
# San Luis Obispo         20.56           57.0    61.538462   171.428571
# Monterey                 5.85           25.0   150.000000    25.000000
# Solano                   8.71           39.0    78.947368    14.705882
# Marin                   14.06           33.0   175.000000    50.000000
# Merced                   9.98           29.0     0.000000    45.000000
# Butte                   11.54           26.0   -29.411765   116.666667
# Shasta                  16.25           27.0    80.000000    50.000000
# Placer                  12.22           45.0   275.000000    50.000000
# Humboldt                18.34           24.0    50.000000     0.000000
# Mendocino               25.84           20.0    28.571429    11.111111
# Santa Cruz               9.65           26.0    26.086957   -10.344828
# Napa                     5.20            8.0   -57.142857   166.666667
# Imperial                19.07           32.0   -25.000000   166.666667
# Madera                   4.87            7.0   116.666667   -46.153846
# Yolo                     4.04           10.0    80.000000    11.111111
# Sutter                  10.35           11.0   -62.500000   266.666667
# Kings                    7.36           10.0   -50.000000   400.000000
# El Dorado               11.72           22.0    42.857143   120.000000
# Nevada                  34.09           30.0    42.857143   200.000000
# Lake                    26.11           17.0     9.523810   -26.086957
# Siskiyou                19.37            7.0     0.000000   250.000000
# Tuolumne                 3.48            2.0   100.000000     0.000000
# Yuba                    10.64            9.0   100.000000    12.500000
# Tehama                   3.38            2.0   -50.000000   100.000000
# Del Norte                9.01            3.0          NaN   200.000000
# Lassen                  18.12            7.0    75.000000     0.000000
# San Benito               6.33            4.0   150.000000   -20.000000
# Colusa                  14.72            3.0          NaN     0.000000
# Inyo                    22.03            3.0   -33.333333    50.000000
# Glenn                   14.87            3.0     0.000000   200.000000
# Amador                  13.07            4.0   400.000000   -20.000000
# Mariposa                 3.87            1.0          NaN   -75.000000
# Calaveras                7.00            2.0    33.333333   -50.000000
# Plumas                   6.28            1.0     0.000000   -50.000000
# Trinity                  0.00            0.0     0.000000  -100.000000
# Sierra                   0.00            0.0     0.000000     0.000000
# Modoc                    0.00            0.0     0.000000     0.000000
# Mono                     0.00            0.0     0.000000     0.000000

# %%
# save file to csv for individual EDA analysis
county_sum.to_csv("/home/thuy/Documents/Data Science/02. DS4A/Capstone_teamrepo/DS4A-TeamProject/data/Merged_deaths_hospital_availability_by_county.csv")
