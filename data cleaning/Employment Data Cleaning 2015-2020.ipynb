# %% [markdown]
# ## Employment Data 2015 -2020
#
# Add Definitions
# Civilian Labor Force: Count?
# Civilian Employment: Count?
# Civilian Unemployment: Count?
# Civilian Unemployment Rate: Per 100k

# %%
# Load packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#load Employment data 2015-2020
df = pd.read_csv("/home/jovyan/Capstone Project Stuff/Data/county_employment.csv",)

#allow max rows to be shown- all data shown 
pd.set_option('display.max_rows', None)
print(df)
# Out:
#       Unnamed: 0                                         Employment  \
# 0              0                               Civilian Labor Force
# 1              1                                Civilian Employment
# 2              2                              Civilian Unemployment
# 3              3                         Civilian Unemployment Rate
# 4              4                               Total All Industries
# 5              5                                         Total Farm
# 6              6                                      Total Nonfarm
# 7              7                                      Total Private
# 8              8                                    Goods Producing
# 9              9                    Mining Logging and Construction
# 10            10                                 Mining and Logging
# 11            11                                       Construction
# 12            12                                      Manufacturing
# ...

# %%
#Only keep rows that match: Civilian labor force,  Civilian employment, Civilian unemployment, and Civilian unemployment rate

#New df that contains rows that match "civilian"
df1 = df[df['Employment'].str.match('Civilian')]

df1
# Out:
#       Unnamed: 0                  Employment     Jan-15     Feb-15     Mar-15  \
# 0              0        Civilian Labor Force    21450.0    21380.0    21420.0
# 1              1         Civilian Employment    19620.0    19620.0    19700.0
# 2              2       Civilian Unemployment     1830.0     1770.0     1720.0
# 3              3  Civilian Unemployment Rate        8.5        8.3        8.0
# 32            32        Civilian Labor Force     7600.0     7550.0     7610.0
# 33            33         Civilian Employment     6490.0     6480.0     6560.0
# 34            34       Civilian Unemployment     1120.0     1070.0     1050.0
# 35            35  Civilian Unemployment Rate       14.7       14.2       13.8
# 62            62        Civilian Labor Force     9820.0     9760.0     9820.0
# 63            63         Civilian Employment     8840.0     8790.0     8860.0
# 64            64       Civilian Unemployment      980.0      970.0      960.0
# ...

# %%
# Save into a CSV file for next step
df1.to_csv("/home/jovyan/Capstone Project Stuff/Data/Cleaned_Civilian_Employment_Data_by_County_2015-2020.csv", index=False)
