# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.5.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
# ...
#   Using cached kiwisolver-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached fonttools-4.28.5-py3-none-any.whl (890 kB)
# ...
#   Using cached Pillow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# ...
#   Using cached scipy-1.7.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Heroin Data without California Total

# %%
#load Heroin Death by County Cleaned df
df = pd.read_csv("Heroin_Deaths_by_County_2015-2020.csv")
df.info
# Out:
# <bound method DataFrame.info of         County  Rates  Counts  Year
# 0      Alameda   0.66    11.0  2015
# 1       Alpine   0.00     0.0  2015
# 2       Amador   0.00     0.0  2015
# 3        Butte   0.44     1.0  2015
# 4    Calaveras   3.28     1.0  2015
# ..         ...    ...     ...   ...
# 355   Tuolumne   0.00     0.0  2020
# 356    Unknown    NaN    24.0  2020
# 357    Ventura   4.04    33.0  2020
# 358       Yolo   1.08     2.0  2020
# 359       Yuba   3.29     3.0  2020
#
# [360 rows x 4 columns]>

# %%
#code to see all values in df; max rows equals none
pd.set_option('display.max_rows', None)
print(df)
# Out:
#               County  Rates  Counts  Year
# 0            Alameda   0.66    11.0  2015
# 1             Alpine   0.00     0.0  2015
# 2             Amador   0.00     0.0  2015
# 3              Butte   0.44     1.0  2015
# 4          Calaveras   3.28     1.0  2015
# 5         California   1.41   581.0  2015
# 6             Colusa   0.00     0.0  2015
# 7       Contra Costa   1.15    13.0  2015
# 8          Del Norte   0.00     0.0  2015
# 9          El Dorado   1.05     2.0  2015
# 10            Fresno   0.26     2.0  2015
# 11             Glenn   0.00     0.0  2015
# 12          Humboldt   3.68     6.0  2015
# 13          Imperial   0.59     1.0  2015
# 14              Inyo   0.00     0.0  2015
# 15              Kern   2.66    24.0  2015
# 16             Kings   0.00     0.0  2015
# 17              Lake   0.00     0.0  2015
# 18            Lassen   0.00     0.0  2015
# 19       Los Angeles   1.16   123.0  2015
# 20            Madera   0.00     0.0  2015
# ...

# %%
#code to drop row numbers with California total 
df.drop(df.index[5], inplace=True)

# %%
#group all the californias together
california_total = df[df["County"] == "California"]
#drop that list
county_heroin = df[df["County"] != "California"]
print(county_heroin["County"].unique())
# Out:
# ['Alameda' 'Alpine' 'Amador' 'Butte' 'Calaveras' 'Colusa' 'Contra Costa'
#  'Del Norte' 'El Dorado' 'Fresno' 'Glenn' 'Humboldt' 'Imperial' 'Inyo'
#  'Kern' 'Kings' 'Lake' 'Lassen' 'Los Angeles' 'Madera' 'Marin' 'Mariposa'
#  'Mendocino' 'Merced' 'Modoc' 'Mono' 'Monterey' 'Napa' 'Nevada' 'Orange'
#  'Placer' 'Plumas' 'Riverside' 'Sacramento' 'San Benito' 'San Bernardino'
#  'San Diego' 'San Francisco' 'San Joaquin' 'San Luis Obispo' 'San Mateo'
#  'Santa Barbara' 'Santa Clara' 'Santa Cruz' 'Shasta' 'Sierra' 'Siskiyou'
#  'Solano' 'Sonoma' 'Stanislaus' 'Sutter' 'Tehama' 'Trinity' 'Tulare'
#  'Tuolumne' 'Unknown' 'Ventura' 'Yolo' 'Yuba']

# %%
county_heroin
# Out:
#               County  Rates  Counts  Year
# 0            Alameda   0.66    11.0  2015
# 1             Alpine   0.00     0.0  2015
# 2             Amador   0.00     0.0  2015
# 3              Butte   0.44     1.0  2015
# 4          Calaveras   3.28     1.0  2015
# 6             Colusa   0.00     0.0  2015
# 7       Contra Costa   1.15    13.0  2015
# 8          Del Norte   0.00     0.0  2015
# 9          El Dorado   1.05     2.0  2015
# 10            Fresno   0.26     2.0  2015
# 11             Glenn   0.00     0.0  2015
# 12          Humboldt   3.68     6.0  2015
# 13          Imperial   0.59     1.0  2015
# 14              Inyo   0.00     0.0  2015
# 15              Kern   2.66    24.0  2015
# 16             Kings   0.00     0.0  2015
# 17              Lake   0.00     0.0  2015
# 18            Lassen   0.00     0.0  2015
# 19       Los Angeles   1.16   123.0  2015
# 20            Madera   0.00     0.0  2015
# 21             Marin   0.00     0.0  2015
# ...

# %%
# Save into a CSV file for next step (cleaning, visualization)
county_heroin.to_csv("/home/jovyan/Capstone Project Stuff/Data/Cleaned_Heroin_Deaths_by_County_2015-2020.csv", index=False)

# %% [markdown]
# ## Prescription Opiods (without California Total)

# %%
#load Prescription Death by County Cleaned df
df2 = pd.read_csv("Presciption_Opiods_Deaths_by_County_2015-2020.csv")
df2.info
# Out:
# <bound method DataFrame.info of               County  Rates  Counts  Year
# 0            Alameda   2.73    50.0  2015
# 1             Alpine   0.00     0.0  2015
# 2             Amador   3.75     2.0  2015
# 3              Butte   6.51    16.0  2015
# 4          Calaveras  14.25     7.0  2015
# 5         California   3.35  1401.0  2015
# 6             Colusa   0.00     0.0  2015
# 7       Contra Costa   3.21    38.0  2015
# 8          Del Norte   4.41     1.0  2015
# 9          El Dorado   2.70     5.0  2015
# 10            Fresno   6.01    55.0  2015
# 11             Glenn   2.59     1.0  2015
# 12          Humboldt  12.59    18.0  2015
# 13          Imperial   2.64     4.0  2015
# 14              Inyo   0.00     0.0  2015
# 15              Kern   6.12    53.0  2015
# 16             Kings   3.42     5.0  2015
# 17              Lake  26.92    19.0  2015
# 18            Lassen  10.51     4.0  2015
# 19       Los Angeles   1.91   205.0  2015
# 20            Madera   5.71    10.0  2015
# ...

# %%
#group all the californias together
california_total2 = df2[df2["County"] == "California"]
#drop that list
county_opioiod_prescription = df2[df2["County"] != "California"]
county_opioiod_prescription
# Out:
#               County  Rates  Counts  Year
# 0            Alameda   2.73    50.0  2015
# 1             Alpine   0.00     0.0  2015
# 2             Amador   3.75     2.0  2015
# 3              Butte   6.51    16.0  2015
# 4          Calaveras  14.25     7.0  2015
# 6             Colusa   0.00     0.0  2015
# 7       Contra Costa   3.21    38.0  2015
# 8          Del Norte   4.41     1.0  2015
# 9          El Dorado   2.70     5.0  2015
# 10            Fresno   6.01    55.0  2015
# 11             Glenn   2.59     1.0  2015
# 12          Humboldt  12.59    18.0  2015
# 13          Imperial   2.64     4.0  2015
# 14              Inyo   0.00     0.0  2015
# 15              Kern   6.12    53.0  2015
# 16             Kings   3.42     5.0  2015
# 17              Lake  26.92    19.0  2015
# 18            Lassen  10.51     4.0  2015
# 19       Los Angeles   1.91   205.0  2015
# 20            Madera   5.71    10.0  2015
# 21             Marin   1.50     3.0  2015
# ...

# %%
# Save into a CSV file for next step (cleaning, visualization)
county_opioiod_prescription.to_csv("/home/jovyan/Capstone Project Stuff/Data/Cleaned_Prescription_Opioid_Deaths_by_County_2015-2020.csv", index=False)
